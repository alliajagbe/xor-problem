# %% [markdown]
# # Required Libraries

# %%
import numpy as np
from tensorflow import keras
from keras.layers import Dense
import matplotlib.pyplot as plt

# %% [markdown]
# # XOR Input and Output Data

# %%
inputs = np.array([[0,0],[0,1],[1,0],[1,1]])
target = np.array([[0],[1],[1],[0]])

# %% [markdown]
# # Creating the Model

# %%
model = keras.Sequential()
model.add(Dense(8, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
learning_rate = 0.1
sgd = keras.optimizers.SGD(lr=learning_rate)
# Out:
# c:\Users\Alli Ajagbe\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# # Compiling the Model

# %%
model.compile(loss='mse', optimizer=sgd)

# %% [markdown]
# # Recording the Learning Rates

# %%
# creating a callback to record learning rates
class LearningRateTracker(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        optimizer = self.model.optimizer
        lr = keras.backend.eval(optimizer.lr)
        print('\nLR: {:.6f}\n'.format(lr))

# %% [markdown]
# # Training the Model

# %%
# training the model and monitoring the convergence and learning rates
converged = False
target_loss = 0.001
losses = []
learning_rates = []

while not converged:
    history = model.fit(inputs, target, epochs=10, verbose=1, callbacks=[LearningRateTracker()])
    losses.append(history.history['loss'][0])
    optimizer = model.optimizer
    lr = keras.backend.eval(optimizer.lr)
    learning_rates.append(lr)
    if history.history['loss'][0] < target_loss:
        converged = True
# Out:
# Epoch 1/10
# 1/1 [==============================] - ETA: 0s - loss: 0.2691
# LR: 0.100000
#
# 1/1 [==============================] - 0s 347ms/step - loss: 0.2691
# Epoch 2/10
# 1/1 [==============================] - ETA: 0s - loss: 0.2684
# LR: 0.100000
#
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2684
# Epoch 3/10
# 1/1 [==============================] - ETA: 0s - loss: 0.2676
# LR: 0.100000
#
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2676
# Epoch 4/10
# 1/1 [==============================] - ETA: 0s - loss: 0.2667
# LR: 0.100000
#
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2667
# Epoch 5/10
# 1/1 [==============================] - ETA: 0s - loss: 0.2659
# LR: 0.100000
#
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2659
# Epoch 6/10
# 1/1 [==============================] - ETA: 0s - loss: 0.2650
# LR: 0.100000
#
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2650
# Epoch 7/10
# ...
